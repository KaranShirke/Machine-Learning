# %%
! pip install pydataset
# Out:
# ...
#   Using cached pydataset-0.2.0.tar.gz (15.9 MB)
# ...
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939430 sha256=d155cb3a60f69460c01d160183cf1b02a17662d2eef3c23b304abbe577d0be48
#   Stored in directory: c:\users\karan\appdata\local\pip\cache\wheels\6b\86\a7\f71cb84c7bff804d83e293615a20c0531234397b796aee2645
# Successfully built pydataset
# ...

# %%
from pydataset import data
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %%
# %matplotlib notebook

# %%
pima = data('Pima.tr')

# %%
pima.plot(kind='scatter', x='skin', y='bmi')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
X_train, X_test, Y_train, Y_test = train_test_split(pima.skin, pima.bmi)

# %%
plt.scatter(X_train, Y_train, label = 'Training Data', color = 'r', alpha = .7)
plt.scatter(X_test, Y_test, label = 'Testing Data', color = 'g', alpha = .7)
plt.title("Test Train Split")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
LR = LinearRegression()
LR.fit(X_train.values.reshape(-1,1), Y_train.values)
# Out:
# LinearRegression()

# %%
prediction = LR.predict(X_test.values.reshape(-1,1))
plt.plot(X_test, prediction, label='Linear Regresion', color='b')
plt.scatter(X_test, Y_test, label='Actul Test Data', color='g', alpha=.7)
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
LR.predict(np.array([[50]]))[0]
# Out:
# 39.145110703129944

# %%
LR.score(X_test.values.reshape(-1,1), Y_test.values)*100
# Out:
# 40.08998084182897
